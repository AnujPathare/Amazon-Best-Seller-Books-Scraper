# %% [markdown]
# # Scraping Amazon Best Seller Books using Python

# %% [markdown]
# #### Project outline
#
# - Here are the steps we'll follow:
# - We're going to scrape https://www.amazon.in/gp/bestsellers/books/
#
# - We'll first get the list of different books. For each book we'll get the book name and book page URL. For each books we'll get the top 50 books.
#
# - For each book we'll grab the Book Name, Author Name, Stars, Number of Reviews, Book_Type, Price and the Book URL.
#
# - For each books we'll create the CSV file in the following format
#
# Book_Name,Author_Name,Book_URL,Edition_Type,Price,Star_Rating,Reviews
#
# Harry Potter and the Philosopher's Stone,J.K. Rowling,https://amazon.in/Harry-Potter-Philosophers-Stone-Rowling-ebook/dp/B019PIOJYU/ref=zg_bs_1318158031_1/000-0000000-0000000?pd_rd_i=B019PIOJYU&psc=1,Kindle Edition,₹299.00,4.7 out of 5 stars,"39,452"
#
# The Silent Patient: The record-breaking, multimillion copy Sunday Times bestselling thriller and Richard & Judy book club pick",Alex Michaelides,https://amazon.in/Silent-Patient-Alex-Michaelides/dp/1409181634/ref=zg_bs_1318158031_2/000-0000000-0000000?pd_rd_i=1409181634&psc=1,Paperback,₹279.00,4.5 out of 5 stars,"92,969"

# %% [markdown]
# ## Tools used to scrape the list of topics from Github
#
# - Requests : to download the page
# - BS4 : to parse and extract information
# - Converting to a Pandas DataFrame

# %%
# !pip install requests --upgrade --quiet
import requests

# %%
url='https://www.amazon.in/gp/bestsellers/books/'
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
len(response.text)
# Out:
# 323337

# %%
page_content = response.text

# %%
page_content[0:500]
# Out:
# '<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="p'

# %%
with open('amazon_bestseller.html',"w", encoding="utf-8") as f:
    f.write(page_content)

# %% [markdown]
# ## Use Beautiful Soup to parse and extract information
# - Parse and explore the structure of downloaded web pages using Beautiful soup.
#
# - Use the right properties and methods to extract the required information.
#
# - Create functions to extract from the page into lists and dictionaries.
#
# - (Optional) Use a REST API to acquire additional information if required.

# %%
# !pip install beautifulsoup4 --upgrade --quiet
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page_content, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.find('title')
# Out:
# <title>Amazon.in Bestsellers: The most popular items in Books</title>

# %%
soup.find('img')
# Out:
# <img alt="" src="https://m.media-amazon.com/images/G/31/social_share/amazon_logo._CB633266945_.png" style="display:none"/>

# %%
selection_class = "_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8"
books_title_tag = soup.find_all('div',{ 'class':selection_class})

# %%
len(books_title_tag)
# Out:
# 36

# %%
books_title_tag=books_title_tag[1:len(books_title_tag)]
books_title_tag[:3]
# Out:
# [<div class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8" role="treeitem"><a href="/gp/bestsellers/books/1318158031">Action &amp; Adventure</a></div>,
#  <div class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8" role="treeitem"><a href="/gp/bestsellers/books/1318052031">Arts, Film &amp; Photography</a></div>,
#  <div class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8" role="treeitem"><a href="/gp/bestsellers/books/1318064031">Biographies, Diaries &amp; True Accounts</a></div>]

# %% [markdown]
# ## Extracting Tittles and URL'S of the books

# %%
## Extracting Tittles and URL'S of the books
def get_topic_titles(soup):
    selection_class = "_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8"
    books_title_tag = soup.find_all('div', {'class':selection_class})
    topic_titles = []
    
    for i in books_title_tag:
        topic_titles.append(i.text.strip())
    return topic_titles

# %%
get_topic_titles(soup)
# Out:
# ['Books',
#  'Action & Adventure',
#  'Arts, Film & Photography',
#  'Biographies, Diaries & True Accounts',
#  'Business & Economics',
#  "Children's Books",
#  'Comics & Mangas',
#  'Computing, Internet & Digital Media',
#  'Crafts, Home & Lifestyle',
#  'Crime, Thriller & Mystery',
#  'Engineering',
#  'Exam Preparation',
#  'Fantasy, Horror & Science Fiction',
#  'Health, Family & Personal Development',
#  'Health, Fitness & Nutrition',
#  'Higher Education Textbooks',
#  'Historical Fiction',
#  'History',
#  'Humour',
#  'Language, Linguistics & Writing',
#  'Law',
#  'Literature & Fiction',
#  'Maps & Atlases',
#  'Medicine & Health Sciences',
#  'Politics',
#  'Reference',
#  'Religion',
#  'Romance',
#  'School Books',
#  'Science & Mathematics',
#  'Sciences, Technology & Medicine',
#  'Society & Social Sciences',
#  'Sports',
#  'Teen & Young Adult',
#  'Textbooks & Study Guides',
#  'Travel']

# %%
def get_topic_urls(soup):
    selection_class="_p13n-zg-nav-tree-all_style_zg-browse-item__1rdKf _p13n-zg-nav-tree-all_style_zg-browse-height-large__1z5B8"
    books_title_tag = soup.find_all('div', {'class': selection_class})
    books_url_tag = soup.find_all('div', {'class': selection_class})
    topic_urls = []
    
    base_url = 'https://www.amazon.in/'
    for tag in books_url_tag:
        try:
            topic_urls.append(base_url + tag.find('a')['href'])
        except:
            topic_urls.append('No URL')
        #print(tag.find('a'))
        #topic_urls.append(base_url + tag.find('a')['href'])
    return topic_urls

# %%
print(len(get_topic_urls(soup)))
# Out:
# 36

# %%
urls = get_topic_urls(soup)
urls
# Out:
# ['No URL',
#  'https://www.amazon.in//gp/bestsellers/books/1318158031',
#  'https://www.amazon.in//gp/bestsellers/books/1318052031',
#  'https://www.amazon.in//gp/bestsellers/books/1318064031',
#  'https://www.amazon.in//gp/bestsellers/books/1318068031',
#  'https://www.amazon.in//gp/bestsellers/books/64619755031',
#  'https://www.amazon.in//gp/bestsellers/books/1318104031',
#  'https://www.amazon.in//gp/bestsellers/books/1318105031',
#  'https://www.amazon.in//gp/bestsellers/books/1318118031',
#  'https://www.amazon.in//gp/bestsellers/books/1318161031',
#  'https://www.amazon.in//gp/bestsellers/books/22960344031',
#  'https://www.amazon.in//gp/bestsellers/books/4149751031',
#  'https://www.amazon.in//gp/bestsellers/books/1402038031',
#  'https://www.amazon.in//gp/bestsellers/books/1318128031',
#  'https://www.amazon.in//gp/bestsellers/books/23033693031',
#  'https://www.amazon.in//gp/bestsellers/books/4149418031',
#  'https://www.amazon.in//gp/bestsellers/books/1318164031',
#  'https://www.amazon.in//gp/bestsellers/books/4149493031',
#  'https://www.amazon.in//gp/bestsellers/books/1318143031',
#  'https://www.amazon.in//gp/bestsellers/books/1318144031',
#  'https://www.amazon.in//gp/bestsellers/books/4149542031',
#  'https://www.amazon.in//gp/bestsellers/books/1318157031',
#  'https://www.amazon.in//gp/bestsellers/books/1318298031',
#  'https://www.amazon.in//gp/bestsellers/books/4149549031',
#  'https://www.amazon.in//gp/bestsellers/books/1318176031',
#  'https://www.amazon.in//gp/bestsellers/books/1318185031',
#  'https://www.amazon.in//gp/bestsellers/books/1318188031',
#  'https://www.amazon.in//gp/bestsellers/books/1318168031',
#  'https://www.amazon.in//gp/bestsellers/books/4149807031',
#  'https://www.amazon.in//gp/bestsellers/books/4149708031',
#  'https://www.amazon.in//gp/bestsellers/books/1318203031',
#  'https://www.amazon.in//gp/bestsellers/books/1318216031',
#  'https://www.amazon.in//gp/bestsellers/books/1318224031',
#  'https://www.amazon.in//gp/bestsellers/books/64619754031',
#  'https://www.amazon.in//gp/bestsellers/books/15417300031',
#  'https://www.amazon.in//gp/bestsellers/books/1318295031']

# %% [markdown]
# ## Import Pandas to create Dataframe

# %%
# !pip install pandas --upgrade --quiet
import pandas as pd

# %%
def scrape_topics():
    url='https://www.amazon.in/gp/bestsellers/books/'
    response = requests.get(url)
    if response.status_code != 200:
        raise Exception('Failed to load page {}'.format(topics_url))
    
    soup = BeautifulSoup(response.text, 'html.parser')
    topics_dict = {
        'title': get_topic_titles(soup),
        'url': get_topic_urls(soup)
    }
    return pd.DataFrame(topics_dict)

# %%
scrape_topics().drop(0,axis=0)
# Out:
#                                     title  \
# 1                      Action & Adventure
# 2                Arts, Film & Photography
# 3    Biographies, Diaries & True Accounts
# 4                    Business & Economics
# 5                        Children's Books
# 6                         Comics & Mangas
# 7     Computing, Internet & Digital Media
# 8                Crafts, Home & Lifestyle
# 9               Crime, Thriller & Mystery
# 10                            Engineering
# 11                       Exam Preparation
# 12      Fantasy, Horror & Science Fiction
# 13  Health, Family & Personal Development
# 14            Health, Fitness & Nutrition
# 15             Higher Education Textbooks
# 16                     Historical Fiction
# 17                                History
# 18                                 Humour
# 19        Language, Linguistics & Writing
# 20                                    Law
# 21                   Literature & Fiction
# 22                         Maps & Atlases
# 23             Medicine & Health Sciences
# 24                               Politics
# 25                              Reference
# 26                               Religion
# 27                                Romance
# 28                           School Books
# 29                  Science & Mathematics
# 30        Sciences, Technology & Medicine
# 31              Society & Social Sciences
# 32                                 Sports
# 33                     Teen & Young Adult
# 34               Textbooks & Study Guides
# 35                                 Travel
#
#                                                   url
# 1   https://www.amazon.in//gp/bestsellers/books/13...
# 2   https://www.amazon.in//gp/bestsellers/books/13...
# 3   https://www.amazon.in//gp/bestsellers/books/13...
# 4   https://www.amazon.in//gp/bestsellers/books/13...
# 5   https://www.amazon.in//gp/bestsellers/books/64...
# 6   https://www.amazon.in//gp/bestsellers/books/13...
# 7   https://www.amazon.in//gp/bestsellers/books/13...
# 8   https://www.amazon.in//gp/bestsellers/books/13...
# 9   https://www.amazon.in//gp/bestsellers/books/13...
# 10  https://www.amazon.in//gp/bestsellers/books/22...
# 11  https://www.amazon.in//gp/bestsellers/books/41...
# 12  https://www.amazon.in//gp/bestsellers/books/14...
# 13  https://www.amazon.in//gp/bestsellers/books/13...
# 14  https://www.amazon.in//gp/bestsellers/books/23...
# 15  https://www.amazon.in//gp/bestsellers/books/41...
# 16  https://www.amazon.in//gp/bestsellers/books/13...
# 17  https://www.amazon.in//gp/bestsellers/books/41...
# 18  https://www.amazon.in//gp/bestsellers/books/13...
# 19  https://www.amazon.in//gp/bestsellers/books/13...
# 20  https://www.amazon.in//gp/bestsellers/books/41...
# 21  https://www.amazon.in//gp/bestsellers/books/13...
# 22  https://www.amazon.in//gp/bestsellers/books/13...
# 23  https://www.amazon.in//gp/bestsellers/books/41...
# 24  https://www.amazon.in//gp/bestsellers/books/13...
# 25  https://www.amazon.in//gp/bestsellers/books/13...
# 26  https://www.amazon.in//gp/bestsellers/books/13...
# 27  https://www.amazon.in//gp/bestsellers/books/13...
# 28  https://www.amazon.in//gp/bestsellers/books/41...
# 29  https://www.amazon.in//gp/bestsellers/books/41...
# 30  https://www.amazon.in//gp/bestsellers/books/13...
# 31  https://www.amazon.in//gp/bestsellers/books/13...
# 32  https://www.amazon.in//gp/bestsellers/books/13...
# 33  https://www.amazon.in//gp/bestsellers/books/64...
# 34  https://www.amazon.in//gp/bestsellers/books/15...
# 35  https://www.amazon.in//gp/bestsellers/books/13...

# %%
element = scrape_topics().loc[1, 'url']
element
# Out:
# 'https://www.amazon.in//gp/bestsellers/books/1318158031'

# %% [markdown]
# ## Extracting Information for all Books

# %%
books_url = 'https://www.amazon.in//gp/bestsellers/books/1318158031'

# %%
response = requests.get(books_url)

# %%
books_doc = BeautifulSoup(response.text, 'html.parser')

# %%
div_tags = books_doc.find_all('div', {'class':"zg-grid-general-faceout"})
#div_tags

# %%
import os

books_doc = BeautifulSoup(response.text, 'html.parser')

books_dict={
        'Book_Name':[],
        'Author_Name':[],
        'Book_URL':[],
        'Edition_Type':[],
        'Price':[],
        'Star_Rating':[],
        'Reviews':[]
    }

def get_topic_page(books_urls):
    # download the page
    books_url='https://www.amazon.in/gp/bestsellers/books/1318158031'
    # check sucessful response
    response=requests.get(books_urls)
    
#     print(response.status_code)
    if response.status_code!=200:
        raise Exception('failed to load page {}'.format(books_urls))
        
    # parse using BeautifulSoup
    topic_doc = BeautifulSoup(response.text, 'html.parser')
    #div_tags= books_doc.find_all('div',{'class':"zg-grid-general-faceout"})
    return topic_doc


def books_details(div_tags):
    
    #extracting book names
    Book_Name_tags =div_tags.find('span')
    
    #extracting author name of books
    Author_Name_tags = div_tags.find('a', class_ = 'a-size-small a-link-child')
    
    #extracting books urls
    Book_URL = 'https://amazon.in' + div_tags.find('a', class_ = 'a-link-normal')['href']
    
    #extracting edition type of books
    Edition_Type_tags = div_tags.find('span', class_ = 'a-size-small a-color-secondary a-text-normal')
    
    #extracting price tag of book
#     Price_tags = div_tags.find('span', class_ = 'p13n-sc-price')
    Price_tags = div_tags.find('span', class_ = '_cDEzb_p13n-sc-price_3mJ9Z')
    
    #extracting star rating of books
    Star_Rating_tags = div_tags.find('span', class_ = 'a-icon-alt')
    
    #extracting review of books
    Reviews_tags = div_tags.find('span', class_ = 'a-size-small')
    
    return Book_Name_tags, Author_Name_tags, Book_URL, Edition_Type_tags, Price_tags, Star_Rating_tags, Reviews_tags


def book_name(books_info):
    if books_info[0] is not None:
        books_dict['Book_Name'].append(books_info[0].text)
    else:
        books_dict['Book_Name'].append('Missing')
    return books_dict


def author_name(books_info):
    if books_info[1] is not None:
        books_dict['Author_Name'].append(books_info[1].text)
    else:
        books_dict['Author_Name'].append('Missing')
    return books_dict


def book_url(books_info):
    if books_info[2] is not None:
        books_dict['Book_URL'].append(books_info[2])
    else:
        books_dict['Book_URL'].append('Missing')
    return books_dict


def edition_type(books_info) :
    if books_info[3] is not None:
        books_dict['Edition_Type'].append(books_info[3].text)
    else:
        books_dict['Edition_Type'].append('Missing')
    return books_dict


def book_price(books_info):
    if books_info[4] is not None:
        return books_dict['Price'].append(books_info[4].text)
    else:
        return books_dict['Price'].append('Missing')
    return books_dict


def star_rating(books_info):
    if books_info[5] is not None:
        books_dict['Star_Rating'].append(books_info[5].text)
    else:
        books_dict['Star_Rating'].append('Missing')
    return books_dict


def book_reviews(books_info):
    if books_info[6] is not None:
        books_dict['Reviews'].append(books_info[6].text)
    else:
        books_dict['Reviews'].append('Missing')
    return books_dict


def get_books(books_doc):
    div_selection_class = 'zg-grid-general-faceout'
    div_tags = books_doc.find_all('div', class_ = div_selection_class ) # creating a dictionary
    
    for i in range(0, len(div_tags)):
        books_info = books_details(div_tags[i])
        book_name(books_info)
        author_name(books_info)
        book_url(books_info)
        edition_type(books_info)
        book_price(books_info)
        star_rating(books_info)
        book_reviews(books_info)
    return pd.DataFrame(books_dict)

# %%
get_books(books_doc)
# Out:
#                                             Book_Name  \
# 0            Harry Potter and the Philosopher's Stone
# 1    THE SILENT PATIENT [Paperback] Michaelides, Alex
# 2   The Hidden Hindu: Science-Fiction meets Indian...
# 3                                  The Hidden Hindu 2
# 4   How the Earth Got Its Beauty: Puffin Chapter B...
# 5               The Complete Novel of Sherlock Holmes
# 6   The Hidden Hindu Book 3 [Paperback] Gupta, Akshat
# 7            War of Lanka (Ram Chandra Series Book 4)
# 34  Missing  4.7 out of 5 stars                    6,384
# 35  Missing  4.7 out of 5 stars                      152
# 36  Missing  4.5 out of 5 stars                   13,631
# 37  Missing  4.4 out of 5 stars     RACHEL RENEE RUSSELL
# 38  Missing  4.6 out of 5 stars                    1,712
# 39  Missing  4.4 out of 5 stars                    4,989
# 40  Missing  4.9 out of 5 stars                      451
# 41  Missing  4.6 out of 5 stars           Amish Tripathi
# 42  Missing  4.7 out of 5 stars                   35,358
# 43  Missing  4.4 out of 5 stars                    6,756
# 44  Missing  4.5 out of 5 stars  Capt. Irfan Sait Razack
# 45  Missing  4.6 out of 5 stars                   18,820
# 46  Missing  4.2 out of 5 stars                      343
# 47  Missing  4.7 out of 5 stars              Sudha Murty
# 48  Missing  4.6 out of 5 stars                    4,241
# 49  Missing  4.3 out of 5 stars                       30

# %%
def scrape_books(books_url, path):
    if os.path.exists(path):
        print('The file {} already exists.. Skipping...'.format(path))
        return
    books_df = get_books(get_topic_page(books_url))
    books_df.to_csv(path, index = None)

def scrape_lists_of_books():
    print('Scraping list of book')
    books_df = scrape_topics()
    books_df = books_df.drop(0,axis=0)
    #print(books_df)
    os.makedirs('data', exist_ok = True)
    for index, row in books_df.iterrows():
        print('Scraping bestselling books details "{}"'.format(row['title']))
        scrape_books(row['url'], 'data/{}.csv'.format(row['title']))

# %%
scrape_lists_of_books()
# Out:
# Scraping list of book
# Scraping bestselling books details "Action & Adventure"
# The file data/Action & Adventure.csv already exists.. Skipping...
# Scraping bestselling books details "Arts, Film & Photography"
# The file data/Arts, Film & Photography.csv already exists.. Skipping...
# Scraping bestselling books details "Biographies, Diaries & True Accounts"
# The file data/Biographies, Diaries & True Accounts.csv already exists.. Skipping...
# Scraping bestselling books details "Business & Economics"
# The file data/Business & Economics.csv already exists.. Skipping...
# Scraping bestselling books details "Children's Books"
# The file data/Children's Books.csv already exists.. Skipping...
# Scraping bestselling books details "Comics & Mangas"
# The file data/Comics & Mangas.csv already exists.. Skipping...
# Scraping bestselling books details "Computing, Internet & Digital Media"
# The file data/Computing, Internet & Digital Media.csv already exists.. Skipping...
# Scraping bestselling books details "Crafts, Home & Lifestyle"
# The file data/Crafts, Home & Lifestyle.csv already exists.. Skipping...
# Scraping bestselling books details "Crime, Thriller & Mystery"
# The file data/Crime, Thriller & Mystery.csv already exists.. Skipping...
# Scraping bestselling books details "Engineering"
# The file data/Engineering.csv already exists.. Skipping...
# Scraping bestselling books details "Exam Preparation"
# The file data/Exam Preparation.csv already exists.. Skipping...
# Scraping bestselling books details "Fantasy, Horror & Science Fiction"
# The file data/Fantasy, Horror & Science Fiction.csv already exists.. Skipping...
# Scraping bestselling books details "Health, Family & Personal Development"
# The file data/Health, Family & Personal Development.csv already exists.. Skipping...
# Scraping bestselling books details "Health, Fitness & Nutrition"
# The file data/Health, Fitness & Nutrition.csv already exists.. Skipping...
# Scraping bestselling books details "Higher Education Textbooks"
# The file data/Higher Education Textbooks.csv already exists.. Skipping...
# Scraping bestselling books details "Historical Fiction"
# The file data/Historical Fiction.csv already exists.. Skipping...
# Scraping bestselling books details "History"
# The file data/History.csv already exists.. Skipping...
# Scraping bestselling books details "Humour"
# The file data/Humour.csv already exists.. Skipping...
# Scraping bestselling books details "Language, Linguistics & Writing"
# The file data/Language, Linguistics & Writing.csv already exists.. Skipping...
# Scraping bestselling books details "Law"
# The file data/Law.csv already exists.. Skipping...
# Scraping bestselling books details "Literature & Fiction"
# The file data/Literature & Fiction.csv already exists.. Skipping...
# Scraping bestselling books details "Maps & Atlases"
# The file data/Maps & Atlases.csv already exists.. Skipping...
# Scraping bestselling books details "Medicine & Health Sciences"
# The file data/Medicine & Health Sciences.csv already exists.. Skipping...
# Scraping bestselling books details "Politics"
# The file data/Politics.csv already exists.. Skipping...
# Scraping bestselling books details "Reference"
# The file data/Reference.csv already exists.. Skipping...
# Scraping bestselling books details "Religion"
# The file data/Religion.csv already exists.. Skipping...
# Scraping bestselling books details "Romance"
# The file data/Romance.csv already exists.. Skipping...
# Scraping bestselling books details "School Books"
# The file data/School Books.csv already exists.. Skipping...
# Scraping bestselling books details "Science & Mathematics"
# The file data/Science & Mathematics.csv already exists.. Skipping...
# Scraping bestselling books details "Sciences, Technology & Medicine"
# The file data/Sciences, Technology & Medicine.csv already exists.. Skipping...
# Scraping bestselling books details "Society & Social Sciences"
# The file data/Society & Social Sciences.csv already exists.. Skipping...
# Scraping bestselling books details "Sports"
# The file data/Sports.csv already exists.. Skipping...
# Scraping bestselling books details "Teen & Young Adult"
# The file data/Teen & Young Adult.csv already exists.. Skipping...
# Scraping bestselling books details "Textbooks & Study Guides"
# The file data/Textbooks & Study Guides.csv already exists.. Skipping...
# Scraping bestselling books details "Travel"
# The file data/Travel.csv already exists.. Skipping...

# %% [markdown]
# ## Summary
#
# ### What we have done so far was
#
# - Install and import libraries.
#
# - Download and Parse the Bestseller HTML page source code using request and Beautifulsoup to get item categories topics URL.
#
# - Extract the Book name,Book urls.
#
# - Extract information from each page.
#
# - Combine the extracted information Extract information from each page’s data in a Python Dictionaries.
#
# - Save the information data to CSV file Using Pandas library.
#
# - By the end of the project, we’ll create a CSV file in the following format:
#
#
# Book_Name,Author_Name,Book_URL,Edition_Type,Price,Star_Rating,Reviews
#
# Harry Potter and the Philosopher's Stone,J.K. Rowling,https://amazon.in/Harry-Potter-Philosophers-Stone-Rowling-ebook/dp/B019PIOJYU/ref=zg_bs_1318158031_1/000-0000000-0000000?pd_rd_i=B019PIOJYU&psc=1,Kindle Edition,₹299.00,4.7 out of 5 stars,"39,452"
#
# The Silent Patient: The record-breaking, multimillion copy Sunday Times bestselling thriller and Richard & Judy book club pick",Alex Michaelides,https://amazon.in/Silent-Patient-Alex-Michaelides/dp/1409181634/ref=zg_bs_1318158031_2/000-0000000-0000000?pd_rd_i=1409181634&psc=1,Paperback,₹279.00,4.5 out of 5 stars,"92,969"
# ```
